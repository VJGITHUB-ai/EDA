# %% [markdown]
# ### IMDB Analysis

# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the CSV file
data = pd.read_csv("C:/Users/Varty/Downloads/IMDB2.csv")
print(data)
# Out:
#                                               Title  IMDb Rating  Year  \
# 0                                  End of the Spear          6.8  2005
# 1                                    Elvira Madigan          7.0  1967
# 2                      The Kid Stays in the Picture          7.3  2002
# 3                                     It Ain't Over          8.2  2022
# 4                                            Mahler          7.0  1974
# ...                                             ...          ...   ...
# 3168  The Lord of the Rings: The Return of the King          9.0  2003
# 3169                               Schindler's List          9.0  1993
# 3170                                The Dark Knight          9.0  2008
# 3171                                  The Godfather          9.2  1972
# 3172                       The Shawshank Redemption          9.3  1994
#
#      Certificates        Genre              Director  \
# 0           PG-13    Adventure             Jim Hanon
# ...

# %%
data.head()
# Out:
#                           Title  IMDb Rating  Year Certificates        Genre  \
# 0              End of the Spear          6.8  2005        PG-13    Adventure
# 1                Elvira Madigan          7.0  1967           PG    Biography
# 2  The Kid Stays in the Picture          7.3  2002            R  Documentary
# 3                 It Ain't Over          8.2  2022           PG  Documentary
# 4                        Mahler          7.0  1974           PG    Biography
#
#            Director                                   Star Cast  MetaScore  \
# 0         Jim Hanon         Louie LeonardoChad AllenJack Guzman       45.0
# 1      Bo Widerberg  Pia DegermarkThommy BerggrenLennart Malmer       66.0
# 2  Nanette Burstein          Robert EvansEddie AlbertPeter Bart       75.0
# 3       Sean Mullin          Andy AndresRoger AngellMarty Appel       79.0
# 4       Ken Russell      Robert PowellGeorgina HaleLee Montague       66.0
#
# ...

# %%
data.tail()
# Out:
#                                               Title  IMDb Rating  Year  \
# 3168  The Lord of the Rings: The Return of the King          9.0  2003
# 3169                               Schindler's List          9.0  1993
# 3170                                The Dark Knight          9.0  2008
# 3171                                  The Godfather          9.2  1972
# 3172                       The Shawshank Redemption          9.3  1994
#
#      Certificates      Genre              Director  \
# 3168        PG-13     Action         Peter Jackson
# 3169            R  Biography      Steven Spielberg
# 3170        PG-13     Action     Christopher Nolan
# 3171            R      Crime  Francis Ford Coppola
# 3172            R      Drama        Frank Darabont
#
#                                           Star Cast  MetaScore  \
# 3168        J.R.R. TolkienFran WalshPhilippa Boyens       94.0
# 3169           Liam NeesonRalph FiennesBen Kingsley       95.0
# ...

# %%
data.describe()
# Out:
#        IMDb Rating         Year    MetaScore  Duration (minutes)
# count  3173.000000  3173.000000  3173.000000         3173.000000
# mean      6.931012  2004.958399    65.993066          116.304822
# std       0.805202    16.819985    11.358619           22.123032
# min       3.900000  1917.000000    20.000000           46.000000
# 25%       6.400000  1997.000000    64.000000          105.000000
# 50%       6.900000  2010.000000    66.000000          116.300000
# 75%       7.500000  2017.000000    69.000000          122.000000
# max       9.500000  2025.000000   100.000000          317.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3173 entries, 0 to 3172
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               3173 non-null   object
#  1   IMDb Rating         3173 non-null   float64
#  2   Year                3173 non-null   int64
#  3   Certificates        3173 non-null   object
#  4   Genre               3173 non-null   object
#  5   Director            3173 non-null   object
#  6   Star Cast           3173 non-null   object
#  7   MetaScore           3173 non-null   float64
#  8   Poster-src          3173 non-null   object
#  9   Duration (minutes)  3173 non-null   float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 248.0+ KB

# %%
print(data.shape)
print(data.shape[0])
print(data.shape[1])
# Out:
# (3173, 10)
# 3173
# 10

# %%
list(data.columns)
# Out:
# ['Title',
#  'IMDb Rating',
#  'Year',
#  'Certificates',
#  'Genre',
#  'Director',
#  'Star Cast',
#  'MetaScore',
#  'Poster-src',
#  'Duration (minutes)']

# %%
data.columns
# Out:
# Index(['Title', 'IMDb Rating', 'Year', 'Certificates', 'Genre', 'Director',
#        'Star Cast', 'MetaScore', 'Poster-src', 'Duration (minutes)'],
#       dtype='object')

# %%
# checking the null values exits or not
data.isnull()
data.isna()
# Out:
#       Title  IMDb Rating   Year  Certificates  Genre  Director  Star Cast  \
# 0     False        False  False         False  False     False      False
# 1     False        False  False         False  False     False      False
# 2     False        False  False         False  False     False      False
# 3     False        False  False         False  False     False      False
# 4     False        False  False         False  False     False      False
# ...     ...          ...    ...           ...    ...       ...        ...
# 3168  False        False  False         False  False     False      False
# 3169  False        False  False         False  False     False      False
# 3170  False        False  False         False  False     False      False
# 3171  False        False  False         False  False     False      False
# 3172  False        False  False         False  False     False      False
#
#       MetaScore  Poster-src  Duration (minutes)
# ...

# %%
data.isnull().sum()
# Out:
# Title                 0
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Poster-src            0
# Duration (minutes)    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Title', 'IMDb Rating', 'Year', 'Certificates', 'Genre', 'Director',
#        'Star Cast', 'MetaScore', 'Poster-src', 'Duration (minutes)'],
#       dtype='object')

# %%
# which movies has same IMDB ratings?
data.groupby('IMDb Rating')['Title'],same_rating_movies[same_rating_movies['Title'].str.len()>2]
# Out:
# (<pandas.core.groupby.generic.SeriesGroupBy object at 0x000002DA5D143920>,
#      IMDb Rating                                              Title
#  4           5.0  [A Serbian Film, A Serbian Film, Mind Runner, ...
#  5           5.1  [Sud sumasshedshikh, Anomaliya, Beyond Redempt...
#  6           5.2  [Alien Protocol, Six-Hundred & Sixty Six, En R...
#  7           5.3  [Neco je ve vzduchu, 6 for 7, The Secret of Im...
#  8           5.4  [Maken Liner 0011 Henshin Seyo!, Le futur aux ...
#  9           5.5  [Five Nights at Freddy's, Five Nights at Fredd...
#  10          5.6  [Pedejais bledis, Uchuujin from Outer Space, I...
#  11          5.7  [Parallel, Gahim taht el-Ma, Off, Entre Oscuro...
#  12          5.8  [Old, Old, Der achte Tag, Murderous Tales, Lig...
#  13          5.9  [Cobweb, The Prodigy, Cobweb, The Prodigy, Gal...
#  14          6.0  [The Devil's Violinist, A Tale of Love and Dar...
#  15          6.1  [Princess Kaiulani, Lisztomania, Stockholm, Li...
# ...

# %%
# what are the movies contain more than 180 minutes runtime?
data[data['Duration (minutes)'] > 250][['Title', 'Duration (minutes)']]
# Out:
#                              Title  Duration (minutes)
# 301   The Greatest Story Ever Told               260.0
# 2408       The Sorrow and the Pity               251.0
# 2572                 Occupied City               266.0
# 2672  The Greatest Story Ever Told               260.0
# 2769                          1900               317.0
# 2828                    Gettysburg               271.0

# %%
# what are the movies directed by peter jackson?
data[data['Director'] == 'Peter Jackson']['Title'].sum()
# Out:
# 'Heavenly CreaturesThe Hobbit: The Desolation of SmaugThe Lord of the Rings: The Two TowersThe Lord of the Rings: The Return of the KingThe Lord of the Rings: The Fellowship of the RingThe Lord of the Rings: The Fellowship of the RingThey Shall Not Grow OldThe Lord of the Rings: The Two TowersThe Lord of the Rings: The Fellowship of the RingThe Lord of the Rings: The Return of the King'

# %%
#what is the count of biography movies Genre?
data[data['Genre'] == 'Biography']['Title'].count()
# Out:
# 868

# %%
#which movies has metascore high and low?
{data.loc[data['MetaScore'].idxmax(), 'Title'], data.loc[data['MetaScore'].idxmax(), 'MetaScore'],
data.loc[data['MetaScore'].idxmin(), 'Title'], data.loc[data['MetaScore'].idxmin(), 'MetaScore']}
# Out:
# {100.0, 20.0, 'Joe Dirt', 'Lawrence of Arabia'}

# %%
# how many movies are released in 2024 with title and duration and thier certificate?
data[(data['Year'] == 2024)][['Title', 'Duration (minutes)', 'Certificates']]
# Out:
#                                        Title  Duration (minutes) Certificates
# 299   Super/Man: The Christopher Reeve Story               106.0        PG-13
# 514                                  Shirley               117.0        PG-13
# 701                  Young Woman and the Sea               129.0           PG
# 711                                  Cabrini               142.0        PG-13
# 712                           The Beach Boys               113.0        PG-13
# ...                                      ...                 ...          ...
# 3019                         Kung Fu Panda 4                94.0           PG
# 3022                            The Fall Guy               126.0        PG-13
# 3051                      Orion and the Dark                93.0        TV-Y7
# 3055                             City Hunter               102.0        TV-MA
# 3152                          Dune: Part Two               166.0        PG-13
#
# [64 rows x 3 columns]

# %%
# how many  movies are with meta score 94.0?
data[data['MetaScore'] == 94.0].shape[0]
# Out:
# 13

# %%
# Plotting the distribution of IMDb ratings
plt.figure(figsize=(10, 6))
sns.histplot(df['IMDb Rating'], bins=20, kde=True)
plt.title('Distribution of IMDb Ratings')
plt.xlabel('IMDb Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# Calculate average IMDb rating by genre
average_rating = data.groupby('Genre')['IMDb Rating'].mean().sort_values()

# Plotting average ratings by genre
plt.figure(figsize=(12, 8))
average_rating.plot(kind='barh')
plt.title('Average IMDb Rating by Genre')
plt.xlabel('Average IMDb Rating')
plt.ylabel('Genre')
plt.show()

# %%
# Sorting the dataset by IMDb rating
top_rated = df.nlargest(10, 'IMDb Rating')

# Plotting the top 10 highest-rated movies
plt.figure(figsize=(12, 6))
sns.barplot(x='IMDb Rating', y='Title', data=top_rated)
plt.title('Top 10 Highest-Rated Movies')
plt.xlabel('IMDb Rating')
plt.ylabel('Movie Title')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[251], line 2
#       1 # Sorting the dataset by IMDb rating
# ----> 2 top_rated = df.nlargest(10, 'IMDb Rating')
#       4 # Plotting the top 10 highest-rated movies
#       5 plt.figure(figsize=(12, 6))
#
# NameError: name 'df' is not defined

# %%
# count of movies by Genre
plt.figure(figsize=(12, 6))
sns.countplot(data=data, y='Genre', order=data['Genre'].value_counts().index)
plt.title('Count of Movies by Genre')
plt.xlabel('Number of Movies')
plt.ylabel('Genre')
plt.show()

# %%
# distribution of meta score
plt.figure(figsize=(10, 6))
sns.histplot(df['MetaScore'], bins=20, kde=True)
plt.title('Distribution of MetaScores')
plt.xlabel('MetaScore')
plt.ylabel('Frequency')
plt.show()

# %%
# Create a scatter plot of IMDb Rating vs. Year
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Year', y='IMDb Rating', data=df, hue='Genre', alpha=0.7, s=50)
plt.title('Scatter Plot of IMDb Rating vs. Year')
plt.xlabel('Year of Release')
plt.ylabel('IMDb Rating')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()
